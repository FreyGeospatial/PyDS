# %%
import pandas as pd
import os
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
os.getcwd()
# Out:
# '/media/freygeospatial/DATADRIVE1/OneDrive/Documents/School_Work/Udemy/LearnPy'

# %%
movies = pd.read_csv("P4-Movie-Ratings.csv")

# %%
len(movies)
# Out:
# 559

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film                         559 non-null object
# Genre                        559 non-null object
# Rotten Tomatoes Ratings %    559 non-null int64
# Audience Ratings %           559 non-null int64
# Budget (million $)           559 non-null int64
# Year of release              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
#rename columns
movies.columns = ['film', 'genre', 'critic_rating', 'audience_rating', \
                 'budget_millions', 'year']

# %%
movies.columns
# Out:
# Index(['film', 'genre', 'critic_rating', 'audience_rating', 'budget_millions',
#        'year'],
#       dtype='object')

# %%
#change data type of column
movies['film'] = movies['film'].astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# film               559 non-null category
# genre              559 non-null object
# critic_rating      559 non-null int64
# audience_rating    559 non-null int64
# budget_millions    559 non-null int64
# year               559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movies['genre'] = movies['genre'].astype('category')
movies['year'] = movies['year'].astype('category')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# film               559 non-null category
# genre              559 non-null category
# critic_rating      559 non-null int64
# audience_rating    559 non-null int64
# budget_millions    559 non-null int64
# year               559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
#view unique categories within dataframe column:
movies.genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe() #categories not included here
# Out:
#        critic_rating  audience_rating  budget_millions
# count     559.000000       559.000000       559.000000
# mean       47.309481        58.744186        50.236136
# std        26.413091        16.826887        48.731817
# min         0.000000         0.000000         0.000000
# 25%        25.000000        47.000000        20.000000
# 50%        46.000000        58.000000        35.000000
# 75%        70.000000        72.000000        65.000000
# max        97.000000        96.000000       300.000000

# %%
#Jointplots
j = sns.jointplot(data=movies, x = 'critic_rating', y = 'audience_rating')

# %%
#Jointplots
j = sns.jointplot(data=movies, x = 'critic_rating', y = 'audience_rating', kind = 'hex')

# %% [markdown]
# ---

# %%
#Histograms

sns.set_style("whitegrid", {"grid.linestyle": '--'})

m1 = sns.distplot(movies['audience_rating'], bins=15, 
                  hist_kws = dict(edgecolor = "k", linewidth = 1))
m1.set(xlim=(0, None))
# Out:
# [(0, 116.45476479376052)]

# %%
sns.set_style("darkgrid", {"grid.linestyle": '--'})
plt.hist(movies['audience_rating'], bins = 15)
# Out:
# (array([ 2.,  0.,  1.,  5., 20., 42., 48., 81., 76., 65., 67., 60., 45.,
#         35., 12.]),
#  array([ 0. ,  6.4, 12.8, 19.2, 25.6, 32. , 38.4, 44.8, 51.2, 57.6, 64. ,
#         70.4, 76.8, 83.2, 89.6, 96. ]),
#  <a list of 15 Patch objects>)

# %%
n1 = plt.hist(movies['critic_rating'], bins = 15)

# %%
#stacked histograms
movies.info()
h1 = plt.hist(movies.budget_millions)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# film               559 non-null category
# genre              559 non-null category
# critic_rating      559 non-null int64
# audience_rating    559 non-null int64
# budget_millions    559 non-null int64
# year               559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
#filtering
movies.genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: genre, Length: 559, dtype: category
# Categories (7, object): [Action, Adventure, Comedy, Drama, Horror, Romance, Thriller]

# %%
movies.genre == "Drama"
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 554    False
# 555    False
# 556    False
# 557    False
# 558    False
# Name: genre, Length: 559, dtype: bool

# %%
movies[movies.genre == 'Drama']
# Out:
#                     film  genre  critic_rating  audience_rating  \
# 10            88 Minutes  Drama              5               51
# 11    A Dangerous Method  Drama             79               89
# 13        A Serious Man   Drama             89               64
# 18          Albert Nobbs  Drama             53               43
# 23       All Good Things  Drama             33               64
# ..                   ...    ...            ...              ...
# 529            War Horse  Drama             77               73
# 532  Water For Elephants  Drama             60               72
# 534     We Own the Night  Drama             55               63
# 541             Whip It   Drama             84               73
# 545        Winter's Bone  Drama             94               73
#
#      budget_millions  year
# 10                30  2007
# 11                20  2011
# 13                 7  2009
# 18                 8  2011
# 23                20  2010
# ..               ...   ...
# ...

# %%
movies[movies.genre == 'Drama'].budget_millions
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: budget_millions, Length: 101, dtype: int64

# %%
plt.hist(movies[movies.genre == 'Action'].budget_millions, bins = 15)
plt.hist(movies[movies.genre == 'Drama'].budget_millions, bins = 15)
plt.hist(movies[movies.genre == 'Thriller'].budget_millions, bins = 15)
#plt.show()
# Out:
# (array([4., 9., 7., 2., 2., 3., 1., 4., 1., 0., 1., 0., 1., 0., 1.]),
#  array([  4.        ,  16.06666667,  28.13333333,  40.2       ,
#          52.26666667,  64.33333333,  76.4       ,  88.46666667,
#         100.53333333, 112.6       , 124.66666667, 136.73333333,
#         148.8       , 160.86666667, 172.93333333, 185.        ]),
#  <a list of 15 Patch objects>)

# %%
budget_list = [movies[movies.genre == 'Action'].budget_millions,
movies[movies.genre == 'Drama'].budget_millions,
movies[movies.genre == 'Thriller'].budget_millions]

# %%
plt.hist(budget_list)
# Out:
# ([array([29., 43., 24., 14., 13., 14., 11.,  3.,  2.,  1.]),
#   array([65., 26.,  8.,  1.,  0.,  1.,  0.,  0.,  0.,  0.]),
#   array([13.,  9.,  6.,  5.,  1.,  1.,  1.,  0.,  0.,  0.])],
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <a list of 3 Lists of Patches objects>)

# %%
plt.hist(budget_list, stacked = True)
# Out:
# ([array([29., 43., 24., 14., 13., 14., 11.,  3.,  2.,  1.]),
#   array([94., 69., 32., 15., 13., 15., 11.,  3.,  2.,  1.]),
#   array([107.,  78.,  38.,  20.,  14.,  16.,  12.,   3.,   2.,   1.])],
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <a list of 3 Lists of Patches objects>)

# %%
movies.genre.cat.categories #like unique()
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
for gen in movies.genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
#stacked bar chart of all categories
mylabels = []

list1 = []
for gen in movies.genre.cat.categories:
    list1.append(movies[movies.genre == gen].budget_millions)
    mylabels.append(gen)
    
h = plt.hist(list1, bins = 30, stacked = True, rwidth = 1, label = mylabels)
plt.legend()

# %%
vis1 = sns.lmplot(data = movies, x = 'critic_rating', y = 'audience_rating', \
                 fit_reg = False, hue = 'genre', \
                 size = 6, aspect = 1)

# %%
k1 = sns.kdeplot(movies.critic_rating, movies.audience_rating, \
                shade = True, shade_lowest = False, cmap = 'Reds')

# %%
#subplots
k2 = sns.kdeplot(movies.budget_millions, movies.audience_rating)

# %%
k3 = sns.kdeplot(movies.budget_millions, movies.critic_rating)

# %%
f, ax = plt.subplots(1, 2) #one row, 2 columns

# %%
f, axes = plt.subplots(1, 2, figsize = (12, 6), sharey = True, sharex = True)
k2 = sns.kdeplot(movies.budget_millions, movies.audience_rating, axes = ax[0]) #ax for axes
k3 = sns.kdeplot(movies.budget_millions, movies.critic_rating, axes = ax[1])

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f04be2f1780>,
# ...
#       dtype=object)

# %%
f, axes = plt.subplots(2, 2, figsize = (12, 6), sharey = True, sharex = True)
k2 = sns.kdeplot(movies.budget_millions, movies.audience_rating, ax = axes[0,0])
k3 = sns.kdeplot(movies.budget_millions, movies.critic_rating, ax = axes[0,1])

# %%
#violin plots
z = sns.violinplot(data = movies, x = 'genre', y='critic_rating')

# %%
w = sns.boxplot(data = movies, x = 'genre', y='critic_rating')

# %%
#creating facet grid
g = sns.FacetGrid(movies, row = 'genre', hue = 'genre', col = 'year')
g = g.map(plt.scatter, 'critic_rating', 'audience_rating')

# %%
#controlling axes
#creating facet grid
g = sns.FacetGrid(movies, row = 'genre', hue = 'genre', col = 'year')
g = g.map(plt.scatter, 'critic_rating', 'audience_rating')
g.set(xlim=(0,100), ylim=(0,100))
#access the facet grid and flatten 2dimensional array
for ax in g.axes.flat:
    ax.plot((20,100), (20,100), c = "gray", ls = "--")
g.add_legend()

# %%
#BUILDING DASHBOARDS

f, axes = plt.subplots(2,2, figsize = (10,10))
k4 = sns.kdeplot(movies.budget_millions, movies.audience_rating, ax = axes[0,0])
k5 = sns.kdeplot(movies.budget_millions, movies.critic_rating, ax = axes[0,1])
k4.set(xlim = (-30,160))
k5.set(xlim = (-30,160))
k4.set(ylim = (-20,160))
k5.set(ylim = (-20,160))
z1 = sns.violinplot(data = movies[movies.genre == 'Drama'], \
                   x = 'year', y = 'critic_rating', ax = axes[1,0])
k1 = sns.kdeplot(movies.critic_rating, movies.audience_rating, \
                shade = True, shade_lowest = False, cmap = 'Reds', ax = axes[1,1])
